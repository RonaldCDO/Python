# %%
pip install graphic
# Out:
# ...
#      |████████████████████████████████| 61kB 7.1MB/s
# ...
#      |████████████████████████████████| 81kB 9.7MB/s
# ...
#   Created wheel for graphic: filename=graphic-1.0.0a6-py2.py3-none-any.whl size=106042 sha256=ba02df9556a99973034d8172b9cd9062ad9d1b828f8f586f7e7894e1796b288a
#   Stored in directory: /root/.cache/pip/wheels/95/2c/a4/ceffa3fad2c4eb77158e767c8b74ffc2d6497ac59560b567b2
# ...
#   Created wheel for neo4j: filename=neo4j-4.3.0-cp37-none-any.whl size=98810 sha256=11a21e5ef61f80a3ab23cf3f66367936f67c0cc861096f96773933b53f45804c
#   Stored in directory: /root/.cache/pip/wheels/58/89/be/812425cb8643b2a4e1367bf7ae1e5e6018c930406538af2632
# Successfully built graphic neo4j
# ...

# %%
import graphic
