# %%
#inteiras

# %% [markdown]
# var_a = 7

# %%
type(var_a)
# Out:
# int

# %%
var_c = 0.00

# %%
type(var_c)
# Out:
# float

# %%
#float e double

# %%
a = 3.14

# %%
type (a)
# Out:
# float

# %%
#strings

# %%
a = "alo"

# %%
type (a)
# Out:
# str

# %%
print (a)
# Out:
# alo

# %%
hello = "Wolrd"

# %%
print (hello)
# Out:
# Wolrd

# %%
type(hello)
# Out:
# str

# %%
texto = "Vamos ver o limite de uma string"

# %%
print (texto)
# Out:
# Vamos ver o limite de uma string

# %%
print ( hello +" "+ texto)
# Out:
# Wolrd Vamos ver o limite de uma string

# %%
first = "Hello "
second = "World!"

# %%
third = first + second

# %%
print (third)
# Out:
# Hello World!

# %%
#Booleanos

# %%
h = True

# %%
type(h)
# Out:
# bool

# %%
k = False

# %%
type(k)
# Out:
# bool

# %%
h != k
# Out:
# True

# %%
h == k
# Out:
# False

# %%
#Declarações Múltiplas

# %%
d1,d2,d3 = "SS", "C3", "CE1"

# %%
print (d1, d2, d3)
# Out:
# SS C3 CE1

# %%
g1 = g2 = g3 = "Python"

# %%
print (g1, g2, g3)
# Out:
# Python Python Python

# %%
idade, nome, vivo = 25, "Ronald", True

# %%
print (idade, nome, vivo)
# Out:
# 25 Ronald True

# %%
#erros de declarações

# %%
#8var = 1
#True = 1
