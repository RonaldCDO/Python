# %%
#listas

# %%
Li = []

# %%
type(Li)
# Out:
# list

# %%
L1 = list()

# %%
type (L1)
# Out:
# list

# %%
N1 = ['Thiago', 'Ronald', 'Naná']
N2 = ['Thiago, Ronald, Naná']

# %%
len (N1)
# Out:
# 3

# %%
len (N2)
# Out:
# 1

# %%
N1
# Out:
# ['Thiago', 'Ronald', 'Naná']

# %%
N2
# Out:
# ['Thiago, Ronald, Naná']

# %%
N1[0]
# Out:
# 'Thiago'

# %%
N2[0]
# Out:
# 'Thiago, Ronald, Naná'

# %%
N1[1]
# Out:
# 'Ronald'

# %%
N1[2]
# Out:
# 'Naná'

# %%
N1[0:3]
# Out:
# ['Thiago', 'Ronald', 'Naná']

# %%
N1[:3]
# Out:
# ['Thiago', 'Ronald', 'Naná']

# %%
N1.append('Lucas')

# %%
N1
# Out:
# ['Thiago', 'Ronald', 'Naná']

# %%
N1.insert(0, 'João')

# %%
N1
# Out:
# ['João', 'Thiago', 'Ronald', 'Naná', 'Lucas']

# %%
del N1[3]

# %%
N1
# Out:
# ['João', 'Thiago', 'Ronald', 'Lucas']

# %%
N1.reverse()

# %%
N1
# Out:
# ['Lucas', 'Ronald', 'Thiago', 'João']

# %%
N1.remove('Ronald')

# %%
N1
# Out:
# ['Lucas', 'Thiago', 'João']
