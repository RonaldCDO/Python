# %%
a = 10
b = 3

# %%
a+b
# Out:
# 13

# %%
a - b
# Out:
# 7

# %%
a * b
# Out:
# 30

# %%
a / b
# Out:
# 3.3333333333333335

# %%
int(a/b)
# Out:
# 3

# %%
c = int(a/b)

# %%
print (c)
# Out:
# 3

# %%
a % b
# Out:
# 1

# %%
name = "Three"

# %%
teste = name +" " + str(c)

# %%
print (teste)
# Out:
# Three 3

# %%
type (teste)
# Out:
# str
