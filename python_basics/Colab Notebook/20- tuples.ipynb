# %%
#Tuplas

# %%
L = [] #listas
D = {} #dictionary
T = () #tuple

# %%
type(T)
# Out:
# tuple

# %%
t = (1,2,3,4,5)

# %%
t.count(1)
# Out:
# 1

# %%
t[2]
# Out:
# 3

# %%
t2 = 'a', 'b', "oi"

# %%
t2
# Out:
# ('a', 'b', 'oi')

# %%
type(t2)
# Out:
# tuple

# %%
t3 = (1, 2, 3, 4, 5)

# %%
l = list(t3)

# %%
l.append(6)

# %%
t4 = tuple(l)

# %%
t4
# Out:
# (1, 2, 3, 4, 5, 6)
