# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
var = "Python"

# %%
type(var)
# Out:
# str

# %%
len(var)
# Out:
# 6

# %%
var[0]
# Out:
# 'P'

# %%
var[5]
# Out:
# 'n'

# %%
name = "Ronald"

# %%
len (name)
# Out:
# 6

# %%
name[5]
# Out:
# 'd'

# %%
name[0]
# Out:
# 'R'

# %%
var.find("n")
# Out:
# 5

# %%
name2 = "alao"

# %%
name2.find("a")
# Out:
# 0
