# %%
#Matrizes

# %%
import numpy as np

# %%
M = np.array([[1,2,3],[3,4,5],[6,7,8]])

# %%
M
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [6, 7, 8]])

# %%
type(M)
# Out:
# numpy.ndarray

# %%
H2 = np.matrix([[1,2,3],[3,4,5],[6,7,8]])

# %%
H2
# Out:
# matrix([[1, 2, 3],
#         [3, 4, 5],
#         [6, 7, 8]])

# %%
type (H2)
# Out:
# numpy.matrix

# %%
M[1,1]
# Out:
# 4

# %%
M[1,0]
# Out:
# 3

# %%
M[:,2]
# Out:
# array([3, 5, 8])

# %%
M[1,:]
# Out:
# array([3, 4, 5])

# %%
M[0,:]
# Out:
# array([1, 2, 3])
