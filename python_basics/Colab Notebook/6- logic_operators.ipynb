# %%
1 == 1
# Out:
# True

# %%
1^1
# Out:
# 0

# %%
1&1
# Out:
# 1

# %%
1&0
# Out:
# 0

# %%
1|0
# Out:
# 1

# %%
0|0
# Out:
# 0

# %%
1!= 1
# Out:
# False

# %%
1 != 0
# Out:
# True

# %%
5 >= 2
# Out:
# True

# %%
5 <= 2
# Out:
# False
