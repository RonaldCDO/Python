# %%
#dictionaries

# %%
family = {"Pai":40, "Mãe": 36, "filhos":1}

# %%
d1 = {"Lívia":30, "Pedro": 12, "Camila":{"idade":10, "altura":1.70}}

# %%
family['animals'] = False

# %%
family
# Out:
# {'Mãe': 36, 'Pai': 40, 'animals': False, 'filhos': 1}

# %%
family ['filhos'] = 2

# %%
family
# Out:
# {'Mãe': 36, 'Pai': 40, 'animals': False, 'filhos': 2}

# %%
d1
# Out:
# {'Camila': {'altura': 1.7, 'idade': 10}, 'Lívia': 30, 'Pedro': 12}

# %%
d1['Camila']
# Out:
# {'altura': 1.7, 'idade': 10}

# %%
d1['Pedro']
# Out:
# 12

# %%
d1.pop('Pedro')
# Out:
# 12

# %%
d1
# Out:
# {'Camila': {'altura': 1.7, 'idade': 10}, 'Lívia': 30}

# %%
d1['Lívia'] = {"idade":30, "altura":1.40}

# %%
d1
# Out:
# {'Camila': {'altura': 1.7, 'idade': 10}, 'Lívia': {'altura': 1.4, 'idade': 30}}

# %%
d1['Camila']
# Out:
# {'altura': 1.7, 'idade': 10}

# %%
d1['Lívia']
# Out:
# {'altura': 1.4, 'idade': 30}
