# %%
l = ["Ronald", 25, "Naná", 19]

# %%
d = {"Ronald":25, "Naná":19}

# %%
type(d)
# Out:
# dict

# %%
d["Ronald"]
# Out:
# 25

# %%
d["Naná"]
# Out:
# 19

# %%
#O Dicionário não possui ordem

# %%
len (d)
# Out:
# 2

# %%
len (l)
# Out:
# 4

# %%
d.keys()
# Out:
# dict_keys(['Ronald', 'Naná'])

# %%
d.values()
# Out:
# dict_values([25, 19])

# %%
d2 = {"Passos":57}

# %%
d.update(d2)

# %%
d
# Out:
# {'Naná': 19, 'Passos': 57, 'Ronald': 25}

# %%
d.pop("Passos")
# Out:
# 57

# %%
d
# Out:
# {'Naná': 19, 'Ronald': 25}

# %%
d.setdefault("Anon",0)
# Out:
# 0

# %%
d
# Out:
# {'Anon': 0, 'Naná': 19, 'Ronald': 25}

# %%
d.clear()

# %%
d
# Out:
# {}
