# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_text(x, y):
  print(x,y)

# %%
print_text("alo", 1)
# Out:
# alo 1

# %%
def potencia(x,y):
  p = x ** y
  return p

# %%
potencia(2,3)
# Out:
# 8

# %%
potencia(1,1)
# Out:
# 1

# %%
potencia(1,0)
# Out:
# 1

# %%
def sum(x,y):
  sum = x+y
  return sum

# %%
sum (1,2)
# Out:
# 3

# %%
def potencia_1(x, n=1):
  pot = x ** n
  return pot

# %%
potencia_1 (1)
# Out:
# 1

# %%
potencia_1 (100,2)
# Out:
# 10000

# %%
def sum(a,b):
  sum = a+b
  return sum

def mult(a,b):
  mult = a*b
  return mult

def operations(a,b):
  out_1 = sum(a,b)
  out_2 = mult(a,b)
   
  return 'Soma = '+ str(out_1) +', Multiplicacao = ' + str(out_2)

# %%
y = operations (1,2)

# %%
type(y)
# Out:
# str

# %%
y
# Out:
# 'Soma = 3, Multiplicacao = 2'

# %%
y1 = operations (10,1)

# %%
y1
# Out:
# 'Soma = 11, Multiplicacao = 10'
