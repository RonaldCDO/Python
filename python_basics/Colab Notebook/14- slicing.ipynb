# %%
#slicing

# %%
frase = "Python eh uma linguagem muito poderosa!"

# %%
frase[0:6]
# Out:
# 'Python'

# %%
frase[0:2]
# Out:
# 'Py'

# %%
frase[:13]
# Out:
# 'Python eh uma'

# %%
frase[-2]
# Out:
# 'a'

# %%
frase[1::1]
# Out:
# 'ython eh uma linguagem muito poderosa!'

# %%
frase[::1]
# Out:
# 'Python eh uma linguagem muito poderosa!'

# %%
frase[::2]
# Out:
# 'Pto hualnugmmiopdrs!'

# %%
frase[::5]
# Out:
# 'Pnuigupo'

# %%
frase[::-1]
# Out:
# '!asoredop otium megaugnil amu he nohtyP'
