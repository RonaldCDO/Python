# %%
#Math Operators

# %%
pow(1,2)
# Out:
# 1

# %%
pow(2,2)
# Out:
# 4

# %%
5%2
# Out:
# 1

# %%
 2**3
# Out:
# 8

# %%
int(3.1)
# Out:
# 3

# %%
float(3.4)
# Out:
# 3.4

# %%
float(5)
# Out:
# 5.0
