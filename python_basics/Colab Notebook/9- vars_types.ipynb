# %%
x = 7

# %%
type (x)
# Out:
# int

# %%
x
# Out:
# 7

# %%
f5 = 60

# %%
_5f = 60

# %%
#"",<>/|\()@#&$^*+-!

# %% [markdown]
# ![image_2021-05-28_085945.png](data:image/png;base64,...)

# %%
var = 3

# %%
Var = 5

# %%
#case sensitive

# %%
var != Var
# Out:
# True
