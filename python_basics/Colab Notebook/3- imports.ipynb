# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from math import *

# %%
sqrt (9)
# Out:
# 3.0

# %%
cos(6)
# Out:
# 0.960170286650366

# %%
cos(3.14)
# Out:
# -0.9999987317275395

# %%
floor(8.9)
# Out:
# 8

# %%
trunc(8.9)
# Out:
# 8

# %%
ceil(8.9)
# Out:
# 9

# %%
round(8.9)
# Out:
# 9

# %%
round (8.5)
# Out:
# 8

# %%
round (8.6)
# Out:
# 9

# %%
ceil (8.5)
# Out:
# 9
