# %%
#Convertendo tipos de Variáveis

# %%
type(3)
# Out:
# int

# %%
type (True)
# Out:
# bool

# %%
type (None)
# Out:
# NoneType

# %%
isinstance(2.0, int)
# Out:
# False

# %%
isinstance(2, int)
# Out:
# True

# %%
isinstance(2.3, float)
# Out:
# True

# %%
isinstance (True, (int, float))
# Out:
# True

# %%
isinstance (1, (bool, float))
# Out:
# False

# %%
isinstance (1.0, (bool, float))
# Out:
# True

# %%
bool(-3)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool('')
# Out:
# False
