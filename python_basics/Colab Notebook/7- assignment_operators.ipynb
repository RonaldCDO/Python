# %%
x = 10

# %%
print(x)
# Out:
# 10

# %%
x = 2

# %%
print (x)
# Out:
# 2

# %%
x + 10
# Out:
# 12

# %%
x += 2

# %%
print (x)
# Out:
# 4

# %%
++x
# Out:
# 4

# %%
print (x)
# Out:
# 4

# %%
x +=x

# %%
print (x)
# Out:
# 8

# %%
print (x-+x)
# Out:
# 0

# %%
x *=2

# %%
print (x)
# Out:
# 16

# %%
x /= 2

# %%
print (x)
# Out:
# 8.0

# %%
type (x)
# Out:
# float

# %%
int (x)
# Out:
# 8

# %%
type(x)
# Out:
# float
