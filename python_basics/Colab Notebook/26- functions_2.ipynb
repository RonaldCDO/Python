# %%
#undefined args -> function

# %%
def soma_valores(*valores):
  soma = 0
  for i in valores:
    soma = soma + i
  return soma

# %%
soma_valores(1,2,3,4,5)
# Out:
# 15

# %%
soma_valores(1,3,4)
# Out:
# 8
